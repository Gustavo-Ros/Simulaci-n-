# %% [markdown]
# <a href="https://colab.research.google.com/github/Gustavo-Ros/Simulacion-1/blob/main/Ejercicio_aprox_funcion.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # EJERCICIO
# Determinar la funciónd edistribución de la siguiente muestra:
#
# $X=\frac{U^{0.135}-(1-U)^{0.135}}{0.1975}$

# %%
import random as rnd
import numpy as np
import matplotlib.pyplot as plt

# %%
def fun(n):
  lista=[]
  for i in range(n):
    u=rnd.random()
    x=(u**0.135-(1-u)**0.135)/0.1975
    lista.append(x)
  plt.hist(lista, bins = 200)
  return lista

# %%
def cdf(muestra):
  n=len(muestra)
  x=np.sort(muestra)
  y=np.arange(0,n)/n
  return x,y

# %%
muestra=fun(10000)
plt.axvline(media,color='red')

# %%
X,Y=cdf(muestra)
media=np.mean(muestra)
var=np.var(muestra)
plt.step(X,Y)

# %% [markdown]
# La función de distribución es **una normal estandar**
#
#
#
#
# 1.   Elemento de lista
# 2.   Elemento de lista

# %% [markdown]
# Funciones de dsitribucion:
#
# *   Cauchy:  C(0,1)
#
# Media: No definida
#
# Varianza: No definida
#
# *   Gamma:   G(0,1)
#
# Media: $\frac{α}{λ}$
#
# Varianza: $\frac{α}{λ^2}$
#
# Función de
# *   Laplace: L(0,1)
# *   Pareto:  $Par(α)$

# %% [markdown]
# FUNCION, CARACTERISTICAS (parámetros, media, var, f(x),F(X),F^-1(x)), COMO GENERALOS, APLICACIONES
