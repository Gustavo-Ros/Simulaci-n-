# %% [markdown]
# <a href="https://colab.research.google.com/github/Gustavo-Ros/Simulacion-1/blob/main/Tarea1_Prueba_Chi.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # CARGA DATOS DE EXCEL

# %%
# %config IPCompleter.greedy=True
import pandas as pd
import numpy as np
import xlrd
import seaborn as sb
import matplotlib.pyplot as plt
from matplotlib.ticker import PercentFormatter

# %%
import pandas as pd
df=pd.read_excel("/content/drive/MyDrive/PDFs/Libro1.xlsx")
df.shape
# Out:
# (10, 10)

# %%
df.head(10)
# Out:
#    Column1  Column2  Column3  Column4  Column5  Column6  Column7  Column8  \
# 0     0.78     0.98     0.24     0.73     0.43     0.16     0.78     0.47
# 1     0.04     0.29     0.68     0.77     0.16     0.03     0.79     0.22
# 2     0.96     0.26     0.91     0.55     0.75     0.55     0.64     0.39
# 3     0.61     0.14     0.38     0.12     0.40     0.74     0.78     0.98
# 4     0.43     0.67     0.62     0.32     0.53     0.54     0.24     0.29
# 5     0.82     0.94     0.19     0.98     0.41     1.00     0.74     0.92
# 6     0.83     0.88     0.18     0.21     0.50     0.13     0.43     0.69
# 7     0.22     0.50     0.16     0.11     0.18     0.89     0.80     0.42
# 8     0.83     0.79     0.65     0.28     0.78     0.49     0.36     0.86
# 9     0.51     0.07     0.18     0.94     0.50     0.22     0.66     0.91
#
#    Column9  Column10
# 0     0.18      0.55
# 1     0.37      0.80
# 2     0.53      0.45
# 3     0.27      0.60
# 4     0.18      0.08
# ...

# %%
import pandas as pd  #Leer datos Excel
import numpy as np
from tabulate import tabulate  #Formato de tabla

cadena = df.to_string(index=False, header=False) #Crea matrix cuadrada
valo=df.iloc[2,2]  #Accede a valor particular
matrix=cadena.split("\n")  # Hace lista de filas
filas=len(cadena.split("\n"))
columnas=len(matrix[0].split()) #Divide valores de fila 0
# Dividir el rango [0, 1] en 5 intervalos
intervalos = np.linspace(0, 1, 6)


numeros = [float(numero) for fila in cadena.split('\n') for numero in fila.split()]

# Contar cuántos números caen en cada intervalo
conteo_por_intervalo = np.histogram(numeros, bins=intervalos)[0]

# Crear DataFrame
resultado = pd.DataFrame(conteo_por_intervalo, columns=["Cantidad"], index=[f"Intervalo {i}" for i in range(1, 6)])

print(numeros[0]-numeros[1])
# Out:
# -0.19999999999999996

# %% [markdown]
# # TABLA DE VALORES DE CHI-CUADRADA

# %%
import pandas as pd  #Leer datos Excel
import numpy as np
from tabulate import tabulate  #Formato de tabla

datos=df.iloc[0:10, 0:10]  #Lee valores

# Rangos
intervalos = [0,0.2, 0.4, 0.6, 0.8, 1]
rangos = pd.cut(datos.values.flatten(), bins=intervalos)

total=rangos.size #Total de valores
fe=total/(len(intervalos)-1) #Frecuencia esperada

#Frecuencia real
f0 = rangos.value_counts()

# Columnas de valores del Data Frame
df_conteo = pd.DataFrame(f0, columns=["f0"])
df_conteo.index.name = 'Intervalos'
df_conteo['fe']=fe
df_conteo['f0-fe'] = df_conteo['f0'] - fe
df_conteo['(f0-fe)^2'] = (df_conteo['f0'] - fe)**2
df_conteo['(f0-fe)^2 / fe'] = (df_conteo['f0'] - fe)**2/fe

df_conteo = df_conteo[['f0', 'fe', 'f0-fe', '(f0-fe)^2', '(f0-fe)^2 / fe']]

suma_chi=df_conteo['(f0-fe)^2 / fe'].sum()
suma_total=df_conteo['f0'].sum()

df_conteo.loc['Suma total'] = [suma_total, '', '', '', suma_chi]

# Prueba chi-cuadrada
chi2, p = chisquare(f_obs=df_conteo['f0'], f_exp=df_conteo['fe'])

# Imprimir tabla
print(tabulate(df_conteo, headers='keys', tablefmt='fancy_grid', floatfmt=".2f"))
print(f"\nEstadístico de prueba chi-cuadrada: {chi2}")
print(f"Valor p: {p}")

# %%
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-8-7c66cd8e4630> in <cell line: 4>()
#       2
#       3 # Supongamos que df_conteo['f0'] y fe son series de pandas
# ----> 4 chi2, p = chisquare(df_conteo['f0'], f_exp=fe)
#       5
#       6 alpha = 0.05
#
# /usr/local/lib/python3.10/dist-packages/scipy/stats/_stats_py.py in chisquare(f_obs, f_exp, ddof, axis)
#    8252
#    8253     """  # noqa
# -> 8254     return power_divergence(f_obs, f_exp=f_exp, ddof=ddof, axis=axis,
#    8255                             lambda_="pearson")
#    8256
#
# /usr/local/lib/python3.10/dist-packages/scipy/stats/_stats_py.py in power_divergence(f_obs, f_exp, ddof, axis, lambda_)
#    8049                    f"of {rtol}, but the percent differences are:\n"
#    8050                    f"{relative_diff}")
# -> 8051             raise ValueError(msg)
#    8052
#    8053     else:
#
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-21-758f2823d90c> in <cell line: 13>()
#      11 cadena_valores = ' '.join(map(str, datos.values.flatten()))
#      12 valores_lista = cadena_valores.split(' ')
# ---> 13 tercer_valor = int(valores_lista)
#      14 print(tercer_valor)
#
# TypeError: int() argument must be a string, a bytes-like object or a real number, not 'list'
