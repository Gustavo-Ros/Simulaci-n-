# %% [markdown]
# <a href="https://colab.research.google.com/github/Gustavo-Ros/Simulacion-1/blob/main/M%C3%A9todo_de_transformada_inversa.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Se aplicará el método de la transformada inversa a la función:
# $$   f(x) =  \left\{ \begin{array}{lcc}  |x| & si & -1 \leq x \leq 1 \\ \\ 0 && \text{otro caso} \end{array} \right. $$
#
# Primero, es necesario porbar que es una fdp:
#
# *   Por se valor absoluto, se cumple que $f(x)\geq0$
# *   $\int_{-1}^1|x|dx=-\int_{-1}^0 xdx+\int_0^1xdx=\frac{1}{2}+\frac{1}{2}=1$

# %% [markdown]
# Luego, es necesario calcular $F(x)$:
# $$   F(x) =  \left\{ \begin{array}{lcc}  -\frac{x^2}{2}+\frac{1}{2} & si & -1 \leq x \leq 0 \\ \\ \frac{x^2}{2}+\frac{1}{2} & si & 0 \leq x \leq 1 \end{array} \right. $$
#
# Este método requiere utilizar la función acumulada inversa:
#
# $$   F^{-1}(U) =  \left\{ \begin{array}{lcc}  \sqrt{1-2u}  & si & 0 \leq U \leq 0.5 \\ \\ \sqrt{2u-1} & si & 0.5 \leq x \leq 1 \end{array} \right. $$

# %%
#Se cargan las librerías
import random as rnd
import numpy as np
import matplotlib.pyplot as plt

# %%
def transf_inv (n):           #Esta función devuelve una lista con las variables aleatorias
  lista=[]                    #   que siguen la distribución f(x)
  for i in range(n):
    u=rnd.random()            # Variable aleatoria u ~ U(0,1)
    if u<=0.5:                # El condicional determina que F^-1(U) se calcula
      x=(1-2*u)**0.5
    else:
      x=-(2*u-1)**0.5
    lista.append(x)           #Se guardan los valores de X ~ f(x)
  return lista

# %%
C=transf_inv(100000)           #Se calculan n varibles con distribución f(x)
plt.hist(C, bins=100)          #Imprime histograma
# Out:
# (array([2025., 2049., 1894., 1920., 1782., 1841., 1757., 1691., 1671.,
#         1602., 1527., 1504., 1484., 1387., 1469., 1360., 1384., 1323.,
#         1272., 1173., 1141., 1094., 1126., 1079.,  982.,  994.,  947.,
#          882.,  820.,  799.,  772.,  746.,  650.,  646.,  646.,  559.,
#          529.,  456.,  474.,  431.,  356.,  304.,  291.,  262.,  236.,
#          167.,  131.,  102.,   51.,   27.,   24.,   58.,  100.,  135.,
#          211.,  198.,  266.,  322.,  363.,  377.,  423.,  464.,  494.,
#          535.,  603.,  619.,  653.,  677.,  722.,  776.,  813.,  830.,
#          948.,  949., 1006., 1004., 1061., 1113., 1182., 1195., 1243.,
#         1262., 1295., 1337., 1444., 1471., 1420., 1491., 1555., 1630.,
#         1621., 1673., 1677., 1729., 1730., 1782., 1838., 1912., 1945.,
#         2009.]),
#  array([-9.99995481e-01, -9.79995611e-01, -9.59995740e-01, -9.39995869e-01,
#         -9.19995999e-01, -8.99996128e-01, -8.79996257e-01, -8.59996386e-01,
#         -8.39996516e-01, -8.19996645e-01, -7.99996774e-01, -7.79996904e-01,
#         -7.59997033e-01, -7.39997162e-01, -7.19997292e-01, -6.99997421e-01,
#         -6.79997550e-01, -6.59997680e-01, -6.39997809e-01, -6.19997938e-01,
#         -5.99998068e-01, -5.79998197e-01, -5.59998326e-01, -5.39998455e-01,
#         -5.19998585e-01, -4.99998714e-01, -4.79998843e-01, -4.59998973e-01,
#         -4.39999102e-01, -4.19999231e-01, -3.99999361e-01, -3.79999490e-01,
#         -3.59999619e-01, -3.39999749e-01, -3.19999878e-01, -3.00000007e-01,
#         -2.80000137e-01, -2.60000266e-01, -2.40000395e-01, -2.20000525e-01,
#         -2.00000654e-01, -1.80000783e-01, -1.60000912e-01, -1.40001042e-01,
#         -1.20001171e-01, -1.00001300e-01, -8.00014297e-02, -6.00015590e-02,
#         -4.00016884e-02, -2.00018177e-02, -1.94699137e-06,  1.99979237e-02,
#          3.99977944e-02,  5.99976651e-02,  7.99975357e-02,  9.99974064e-02,
#          1.19997277e-01,  1.39997148e-01,  1.59997018e-01,  1.79996889e-01,
#          1.99996760e-01,  2.19996631e-01,  2.39996501e-01,  2.59996372e-01,
#          2.79996243e-01,  2.99996113e-01,  3.19995984e-01,  3.39995855e-01,
#          3.59995725e-01,  3.79995596e-01,  3.99995467e-01,  4.19995337e-01,
#          4.39995208e-01,  4.59995079e-01,  4.79994949e-01,  4.99994820e-01,
#          5.19994691e-01,  5.39994562e-01,  5.59994432e-01,  5.79994303e-01,
#          5.99994174e-01,  6.19994044e-01,  6.39993915e-01,  6.59993786e-01,
#          6.79993656e-01,  6.99993527e-01,  7.19993398e-01,  7.39993268e-01,
#          7.59993139e-01,  7.79993010e-01,  7.99992880e-01,  8.19992751e-01,
#          8.39992622e-01,  8.59992492e-01,  8.79992363e-01,  8.99992234e-01,
#          9.19992105e-01,  9.39991975e-01,  9.59991846e-01,  9.79991717e-01,
#          9.99991587e-01]),
#  <BarContainer object of 100 artists>)

# %%
def acumulativa (muestra):        #Esta función devuelve las coordenadas para graficar F^-1 (x)
  n=len(muestra)
  x=np.sort(muestra)
  y=np.arange(0,n)/n
  return x,y

# %%
X,Y=acumulativa(C)                #Se imprime F^-1{x}
plt.step(X,Y)
plt.title('F^-1 (x)')
plt.xlabel("x")
plt.ylabel("F(x)")
# Out:
# Text(0, 0.5, 'F(x)')
