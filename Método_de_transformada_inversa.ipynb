# %% [markdown]
# <a href="https://colab.research.google.com/github/Gustavo-Ros/Simulacion-1/blob/main/M%C3%A9todo_de_transformada_inversa.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Se aplicará el método de la transformada inversa a la función:
# $$   f(x) =  \left\{ \begin{array}{lcc}  |x| & si & -1 \leq x \leq 1 \\ \\ 0 && \text{otro caso} \end{array} \right. $$
#
# Primero, es necesario porbar que es una fdp:
#
# *   Por se valor absoluto, se cumple que $f(x)\geq0$
# *   $\int_{-1}^1|x|dx=-\int_{-1}^0 xdx+\int_0^1xdx=\frac{1}{2}+\frac{1}{2}=1$

# %% [markdown]
# Luego, es necesario calcular $F(x)$:
# $$   F(x) =  \left\{ \begin{array}{lcc}  -\frac{x^2}{2}+\frac{1}{2} & si & -1 \leq x \leq 0 \\ \\ \frac{x^2}{2}+\frac{1}{2} & si & 0 \leq x \leq 1 \end{array} \right. $$
#
# Este método requiere utilizar la función acumulada inversa:
#
# $$   F^{-1}(U) =  \left\{ \begin{array}{lcc}  \sqrt{1-2u}  & si & 0 \leq U \leq 0.5 \\ \\ \sqrt{2u-1} & si & 0.5 \leq x \leq 1 \end{array} \right. $$

# %%
#Se cargan las librerías
import random as rnd
import numpy as np
import matplotlib.pyplot as plt

# %%
def transf_inv (n):           #Esta función devuelve una lista con las variables aleatorias
  lista=[]                    #   que siguen la distribución f(x)
  for i in range(n):
    u=rnd.random()            # Variable aleatoria u ~ U(0,1)
    if u<=0.5:                # El condicional determina que F^-1(U) se calcula
      x=(1-2*u)**0.5
    else:
      x=-(2*u-1)**0.5
    lista.append(x)           #Se guardan los valores de X ~ f(x)
  return lista

# %%
C=transf_inv(100000)           #Se calculan n varibles con distribución f(x)
plt.hist(C, bins=100)          #Imprime histograma
# Out:
# (array([1971., 1951., 1897., 1893., 1853., 1749., 1784., 1719., 1673.,
#         1691., 1612., 1509., 1554., 1449., 1397., 1418., 1326., 1289.,
#         1284., 1209., 1174., 1100., 1120., 1051., 1015.,  929.,  944.,
#          882.,  828.,  798.,  831.,  723.,  649.,  642.,  630.,  580.,
#          530.,  521.,  472.,  410.,  377.,  334.,  316.,  227.,  219.,
#          164.,  154.,  110.,   61.,   25.,   20.,   65.,   90.,  132.,
#          189.,  212.,  262.,  294.,  329.,  355.,  410.,  453.,  492.,
#          517.,  592.,  607.,  643.,  684.,  744.,  776.,  795.,  908.,
#          901.,  937., 1004.,  967., 1063., 1110., 1104., 1202., 1186.,
#         1331., 1295., 1422., 1381., 1415., 1483., 1566., 1579., 1565.,
#         1568., 1657., 1688., 1687., 1739., 1832., 1898., 1832., 1915.,
#         2060.]),
#  array([-9.99992809e-01, -9.79993011e-01, -9.59993212e-01, -9.39993414e-01,
#         -9.19993616e-01, -8.99993817e-01, -8.79994019e-01, -8.59994221e-01,
#         -8.39994423e-01, -8.19994624e-01, -7.99994826e-01, -7.79995028e-01,
#         -7.59995229e-01, -7.39995431e-01, -7.19995633e-01, -6.99995835e-01,
#         -6.79996036e-01, -6.59996238e-01, -6.39996440e-01, -6.19996641e-01,
#         -5.99996843e-01, -5.79997045e-01, -5.59997247e-01, -5.39997448e-01,
#         -5.19997650e-01, -4.99997852e-01, -4.79998054e-01, -4.59998255e-01,
#         -4.39998457e-01, -4.19998659e-01, -3.99998860e-01, -3.79999062e-01,
#         -3.59999264e-01, -3.39999466e-01, -3.19999667e-01, -2.99999869e-01,
#         -2.80000071e-01, -2.60000272e-01, -2.40000474e-01, -2.20000676e-01,
#         -2.00000878e-01, -1.80001079e-01, -1.60001281e-01, -1.40001483e-01,
#         -1.20001684e-01, -1.00001886e-01, -8.00020878e-02, -6.00022896e-02,
#         -4.00024913e-02, -2.00026930e-02, -2.89470984e-06,  1.99969036e-02,
#          3.99967019e-02,  5.99965001e-02,  7.99962984e-02,  9.99960967e-02,
#          1.19995895e-01,  1.39995693e-01,  1.59995492e-01,  1.79995290e-01,
#          1.99995088e-01,  2.19994886e-01,  2.39994685e-01,  2.59994483e-01,
#          2.79994281e-01,  2.99994080e-01,  3.19993878e-01,  3.39993676e-01,
#          3.59993474e-01,  3.79993273e-01,  3.99993071e-01,  4.19992869e-01,
#          4.39992668e-01,  4.59992466e-01,  4.79992264e-01,  4.99992062e-01,
#          5.19991861e-01,  5.39991659e-01,  5.59991457e-01,  5.79991256e-01,
#          5.99991054e-01,  6.19990852e-01,  6.39990650e-01,  6.59990449e-01,
#          6.79990247e-01,  6.99990045e-01,  7.19989843e-01,  7.39989642e-01,
#          7.59989440e-01,  7.79989238e-01,  7.99989037e-01,  8.19988835e-01,
#          8.39988633e-01,  8.59988431e-01,  8.79988230e-01,  8.99988028e-01,
#          9.19987826e-01,  9.39987625e-01,  9.59987423e-01,  9.79987221e-01,
#          9.99987019e-01]),
#  <BarContainer object of 100 artists>)

# %%
def acumulativa (muestra):        #Esta función devuelve las coordenadas para graficar F^-1 (x)
  n=len(muestra)
  x=np.sort(muestra)
  y=np.arange(0,n)/n
  return x,y

# %%
X,Y=acumulativa(C)                #Se imprime F^-1{x}
plt.step(X,Y)
plt.title('F^-1 (x)')
plt.xlabel("x")
plt.ylabel("F(x)")
# Out:
# Text(0, 0.5, 'F(x)')
